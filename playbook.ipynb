# %%
from community import community
import json

# %%
board = community.discourse()

# %%
json.loads(board.GET('users/polv'))
# Out:
# {'badge_types': [{'id': 2, 'name': 'Silver', 'sort_order': 8},
#   {'id': 1, 'name': 'Gold', 'sort_order': 9}],
#  'badges': [{'allow_title': True,
#    'badge_grouping_id': 4,
#    'badge_type_id': 2,
#    'description': '<a href="https://meta.discourse.org/t/what-do-user-trust-levels-do/4924/6">Granted</a> recategorize, rename, followed links, wiki, more likes',
#    'enabled': True,
#    'grant_count': 73,
#    'icon': 'fa-user',
#    'id': 3,
#    'image': None,
#    'listable': True,
#    'manually_grantable': False,
#    'multiple_grant': False,
#    'name': 'Regular',
#    'slug': 'regular',
#    'system': True},
#   {'allow_title': False,
#    'badge_grouping_id': 2,
#    'badge_type_id': 1,
#    'description': 'Has 500 liked posts and gave 1000 likes',
#    'enabled': True,
#    'grant_count': 31,
#    'icon': 'fa-heart',
#    'id': 39,
#    'image': None,
#    'listable': True,
#    'manually_grantable': False,
#    'multiple_grant': False,
#    'name': 'Empathetic',
# ...
